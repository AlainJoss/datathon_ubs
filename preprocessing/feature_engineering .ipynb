# %% [markdown]
# <h1 style="color:DarkRed;">UBS Challenge: 4ML. Feature Engineering</h1>

# %%
# Feature Engineering and adding Ticks

# %%
import pandas as pd
import yfinance as yf

# %%
cleaned_df = pd.read_csv("cleaned_data.csv")

# %%
cleaned_df
# Out:
#       legal_entity_name period_end_date Ticker  followers  pictures  videos
# 0                AbbVie      2021-07-24   ABBV     5477.0       3.0     4.0  \
# 1                AbbVie      2021-07-31   ABBV     5761.0       5.0     4.0
# 2                AbbVie      2021-08-07   ABBV     5933.0       5.0     3.0
# 3                AbbVie      2021-08-14   ABBV     6104.0       5.0     3.0
# 4                AbbVie      2021-08-21   ABBV     6354.0       5.0     2.0
# ...                 ...             ...    ...        ...       ...     ...
# 75028       iRobot Corp      2023-08-19   IRBT   307679.0      90.0    59.0
# 75029       iRobot Corp      2023-08-26   IRBT   307842.0      96.0    74.0
# 75030       iRobot Corp      2023-09-02   IRBT   307980.0      94.0    71.0
# 75031       iRobot Corp      2023-09-09   IRBT   308043.0      89.0    90.0
# 75032       iRobot Corp      2023-09-16   IRBT   308260.0      98.0    96.0
#
# ...

# %%
cleaned_df['period_end_date'] = pd.to_datetime(cleaned_df['period_end_date'])

# %%
def fetch_yahoo_finance_data(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    # Fetch historical data within the specified date range and interval
    hist = stock.history(start=start_date, end=end_date, interval="1wk")
    hist.reset_index(inplace=True)
    hist["Ticker"] = ticker  # Add a column to identify the ticker
    return hist

# %%
tickers = cleaned_df["Ticker"].unique()
finance_data = []

# %%
for ticker in tickers:
    dates_of_interest = cleaned_df[cleaned_df["Ticker"]==ticker]["period_end_date"]
    yahoo_data = fetch_yahoo_finance_data(ticker, min(dates_of_interest), max(dates_of_interest) + pd.Timedelta(days=7))
    finance_data.append(yahoo_data)

finance_data = pd.concat(finance_data, ignore_index=True)

finance_data
# Out:
# ANFANF: No timezone found, symbol may be delisted
# ADS.DEADS.DE: No timezone found, symbol may be delisted
# AEOAEO: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# BUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUDBUD: No timezone found, symbol may be delisted
# ...

# %%
finance_data
# Out:
#                             Date        Open        High         Low
# 0      2021-07-26 00:00:00-04:00  105.964742  106.879704  104.161741  \
# 1      2021-08-02 00:00:00-04:00  104.852430  105.166385  102.645767
# 2      2021-08-09 00:00:00-04:00  102.780314  104.735814  101.291261
# 3      2021-08-16 00:00:00-04:00  104.951107  107.570398  104.242462
# 4      2021-08-23 00:00:00-04:00  107.462756  108.897984  106.224867
# ...                          ...         ...         ...         ...
# 39620  2023-08-21 00:00:00-04:00   37.119999   39.310001   36.599998
# 39621  2023-08-28 00:00:00-04:00   39.060001   39.500000   38.169998
# 39622  2023-09-04 00:00:00-04:00   38.040001   38.709999   36.160000
# 39623  2023-09-11 00:00:00-04:00   35.840000   36.320000   34.889999
# 39624  2023-09-18 00:00:00-04:00   35.009998   38.290001   34.330002
#
#             Close      Volume  Dividends  Stock Splits Ticker  Adj Close
# ...

# %%
# We have two days delay in the stock price (which is good because is Monday)

# %%
 # Let´s only keep the Closing price (of "next monday") for predicting purposes and Date, with some transformations
    
finance_data["Date"] = finance_data["Date"].map(lambda x: str(x).split(" ")[0])

# %%
finance_data_cleaned = finance_data[["Date", "Close", "Ticker"]]

# %%
# Let´s keep only the observations we will need:

# %%
cleaned_df['period_end_date'] = pd.to_datetime(cleaned_df['period_end_date'])

# Convert 'Date' in finance_data_cleaned to datetime
finance_data_cleaned['Date'] = pd.to_datetime(finance_data_cleaned['Date'])

# Add 2 days to 'period_end_date' in cleaned_df to account for the delay
cleaned_df['period_end_date_adjusted'] = cleaned_df['period_end_date'] + pd.Timedelta(days=9)

# Now perform the merge using the adjusted period_end_date
data_completed = pd.merge(cleaned_df, finance_data_cleaned, left_on=['Ticker', "period_end_date_adjusted"], right_on=['Ticker', "Date"], how='inner')
# Out:
# /var/folders/ff/76sw_qpn335gd_mh170rpmbm0000gn/T/ipykernel_57726/2051376822.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finance_data_cleaned['Date'] = pd.to_datetime(finance_data_cleaned['Date'])

# %%
data_completed_model = data_completed.drop(columns=["compset_group_Beauty & Personal Care", "compset_group_Food & Beverages", "compset_group_Home Improvement & Appliances", "compset_group_Luxury & Premium & Mainstream & Entertainment", "compset_group_Retail"])

# %% [markdown]
# Now, we have the data ready. Let´s start creating some variables:
#
# - Content Variable = pictures + videos: We assume that the effect of a video or of a picture will be the same
# - Likes per Content = Likes/Content: To get an estimator of the amount of likes per content
# - Comments per Likes: We dont think comments by themselves are relevant for the analysis, as they could be either possitive or negatives. However, if we calculate the ratio between comments and likes we could get an estimation of its sentiment.
# - The weekly change of the followers, Likes per content, conments per Likes and the closing stock price
# - Moving Averages to extract information about the trend and be able to identify better the anomalies

# %%
data_completed_model["content"] = data_completed_model["pictures"] + data_completed_model["videos"]
data_completed_model["likes_per_content"] = data_completed_model["likes"]/data_completed_model["content"]
data_completed_model["comments_per_likes"] = data_completed_model["comments"]/data_completed_model["likes"]

# %%
for company in data_completed_model.legal_entity_name.unique():
    company_mask = data_completed_model["legal_entity_name"] == company
    data_completed_model.loc[company_mask, 'likes_per_content_weekly_change'] = data_completed_model.loc[company_mask, 'likes_per_content'].pct_change() * 100
    data_completed_model.loc[company_mask, 'followers_weekly_change'] = data_completed_model.loc[company_mask, 'followers'].pct_change() * 100
    data_completed_model.loc[company_mask, 'comments_per_likes_weekly_change'] = data_completed_model.loc[company_mask, 'comments_per_likes'].pct_change() * 100
    data_completed_model.loc[company_mask, 'Close_price_weekly_change'] = data_completed_model.loc[company_mask, 'Close'].pct_change() * 100

# %%
data_completed_model
# Out:
#       legal_entity_name period_end_date Ticker  followers  pictures  videos
# 0                AbbVie      2021-07-24   ABBV     5477.0       3.0     4.0  \
# 1                AbbVie      2021-07-31   ABBV     5761.0       5.0     4.0
# 2                AbbVie      2021-08-07   ABBV     5933.0       5.0     3.0
# 3                AbbVie      2021-08-14   ABBV     6104.0       5.0     3.0
# 4                AbbVie      2021-08-21   ABBV     6354.0       5.0     2.0
# ...                 ...             ...    ...        ...       ...     ...
# 31970       iRobot Corp      2023-08-12   IRBT   307626.0      90.0    58.0
# 31971       iRobot Corp      2023-08-19   IRBT   307679.0      90.0    59.0
# 31972       iRobot Corp      2023-08-26   IRBT   307842.0      96.0    74.0
# 31973       iRobot Corp      2023-09-02   IRBT   307980.0      94.0    71.0
# 31974       iRobot Corp      2023-09-09   IRBT   308043.0      89.0    90.0
#
# ...

# %%
for company in data_completed_model.legal_entity_name.unique():
    company_mask = data_completed_model["legal_entity_name"] == company
    
    data_completed_model.loc[company_mask, 'comments_per_likes_ma_2'] = data_completed_model.loc[company_mask, 'comments_per_likes'].rolling(window=2).mean()
    data_completed_model.loc[company_mask, 'change_followers_ma_2'] = data_completed_model.loc[company_mask, 'followers_weekly_change'].rolling(window=2).mean()
    data_completed_model.loc[company_mask, 'Close_price_weekly_change_ma_2'] = data_completed_model.loc[company_mask, 'Close_price_weekly_change'].rolling(window=2).mean()
    
    data_completed_model.loc[company_mask, 'comments_per_likes_ma_3'] = data_completed_model.loc[company_mask, 'comments_per_likes'].rolling(window=3).mean()
    data_completed_model.loc[company_mask, 'change_followers_ma_3'] = data_completed_model.loc[company_mask, 'followers_weekly_change'].rolling(window=3).mean()    
    data_completed_model.loc[company_mask, 'Close_price_weekly_change_ma_3'] = data_completed_model.loc[company_mask, 'Close_price_weekly_change'].rolling(window=3).mean()
    
    data_completed_model.loc[company_mask, 'comments_per_likes_ma_5'] = data_completed_model.loc[company_mask, 'comments_per_likes'].rolling(window=5).mean()
    data_completed_model.loc[company_mask, 'change_followers_ma_5'] = data_completed_model.loc[company_mask, 'followers_weekly_change'].rolling(window=5).mean()
    data_completed_model.loc[company_mask, 'Close_price_weekly_change_ma_5'] = data_completed_model.loc[company_mask, 'Close_price_weekly_change'].rolling(window=5).mean()

# %%
# Let´s set to zero the comments_per_likes_weekly_change that are Na (they are originated because of value 0 in the comments of the last weeks)

data_completed_model['comments_per_likes_weekly_change'] = data_completed_model['comments_per_likes_weekly_change'].fillna(0)

# %%
data_completed_model.dropna(inplace=True)

# %%
data_completed_model.to_csv("data_completed_model.csv", index = False)

# %%
data_completed_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30289 entries, 5 to 31974
# Data columns (total 27 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   legal_entity_name                 30289 non-null  object
#  1   period_end_date                   30289 non-null  datetime64[ns]
#  2   Ticker                            30289 non-null  object
#  3   followers                         30289 non-null  float64
#  4   pictures                          30289 non-null  float64
#  5   videos                            30289 non-null  float64
#  6   comments                          30289 non-null  float64
#  7   likes                             30289 non-null  float64
#  8   period_end_date_adjusted          30289 non-null  datetime64[ns]
#  9   Date                              30289 non-null  datetime64[ns]
#  10  Close                             30289 non-null  float64
# ...
